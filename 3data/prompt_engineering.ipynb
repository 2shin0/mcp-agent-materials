# %% [markdown]
# # LLM을 활용한 Data Analaysis
#
# ---

# %% [markdown]
# ## ✔ 예제 데이터 1

# %%
[
  {
    "title": "10월 22일 오늘의 주요 뉴스 | 경제·정치·사회 한눈에 보기",
    "publishedDate": "2025-10-22T09:00:00Z",
    "channelName": "YTN 뉴스",
    "channelId": "UCYTN1234",
    "thumbnailUrl": "https://i.ytimg.com/vi/ytnews001/high.jpg",
    "viewCount": 485321,
    "likeCount": 6100,
    "url": "https://www.youtube.com/watch?v=ytnews001"
  },
  {
    "title": "속보: 한반도 외교 정상회담 주요 합의 내용 정리",
    "publishedDate": "2025-10-21T18:30:00Z",
    "channelName": "KBS News",
    "channelId": "UCKBS5678",
    "thumbnailUrl": "https://i.ytimg.com/vi/kbsnews002/high.jpg",
    "viewCount": 392144,
    "likeCount": 5200,
    "url": "https://www.youtube.com/watch?v=kbsnews002"
  },
  {
    "title": "오늘의 경제 브리핑: 원·달러 환율 급등, 증시 하락세",
    "publishedDate": "2025-10-22T07:30:00Z",
    "channelName": "연합뉴스TV",
    "channelId": "UCYONews9988",
    "thumbnailUrl": "https://i.ytimg.com/vi/yonnews003/high.jpg",
    "viewCount": 276901,
    "likeCount": 3100,
    "url": "https://www.youtube.com/watch?v=yonnews003"
  },
  {
    "title": "정치 현안 브리핑: 국회 본회의 주요 발언 요약",
    "publishedDate": "2025-10-21T15:00:00Z",
    "channelName": "MBC News",
    "channelId": "UCMBC8765",
    "thumbnailUrl": "https://i.ytimg.com/vi/mbcnews004/high.jpg",
    "viewCount": 189324,
    "likeCount": 2800,
    "url": "https://www.youtube.com/watch?v=mbcnews004"
  },
  {
    "title": "국제 뉴스: 미국 대선 경합주 판세 요약 (2025-10-22)",
    "publishedDate": "2025-10-22T10:15:00Z",
    "channelName": "BBC Korean",
    "channelId": "UCBBCKR777",
    "thumbnailUrl": "https://i.ytimg.com/vi/bbcnews005/high.jpg",
    "viewCount": 315776,
    "likeCount": 4200,
    "url": "https://www.youtube.com/watch?v=bbcnews005"
  }
]

# %% [markdown]
# ## ✔ 예제 데이터 2

# %%
# Tool 1 유튜브 영상 URL 자막 추출 예시
{
  "videoUrl": "https://www.youtube.com/watch?v=dQw4w9WgXcQ",
  "videoId": "dQw4w9WgXcQ",
  "language": "en",
  "transcript": "We're no strangers to love. You know the rules and so do I. A full commitment's what I'm thinking of..."
}

# Tool 2 유튜브 영상 검색 및 세부 정보 추출 예시
[
  {
    "title": "AI News Today: OpenAI’s Latest Update Explained",
    "publishedDate": "2025-10-20T10:45:00Z",
    "channelName": "TechWorld AI",
    "channelId": "UCXyTech001AI",
    "thumbnailUrl": "https://i.ytimg.com/vi/abcd1234xyz/hqdefault.jpg",
    "viewCount": 128450,
    "likeCount": 5200,
    "url": "https://www.youtube.com/watch?v=abcd1234xyz"
  },
  {
    "title": "How AI is Changing the Future of Journalism",
    "publishedDate": "2025-10-18T08:12:00Z",
    "channelName": "AI Explained",
    "channelId": "UCaiExp5678",
    "thumbnailUrl": "https://i.ytimg.com/vi/efgh5678lmn/hqdefault.jpg",
    "viewCount": 98500,
    "likeCount": 3100,
    "url": "https://www.youtube.com/watch?v=efgh5678lmn"
  }
]

# Tool 3 YouTube 동영상 URL로부터 채널 정보와 최근 5개 동영상 조회 예시
{
  "channelTitle": "TechWorld AI",
  "channelUrl": "https://www.youtube.com/channel/UCXyTech001AI",
  "subscriberCount": "845000",
  "viewCount": "124502341",
  "videoCount": "284",
  "videos": [
    {
      "title": "AI Revolution 2025: What’s Next?",
      "url": "https://www.youtube.com/watch?v=aiNext2025",
      "published": "2025-10-21T12:00:00Z",
      "thumbnail": "https://i.ytimg.com/vi/aiNext2025/hqdefault.jpg"
    },
    {
      "title": "Google DeepMind New Model vs OpenAI GPT-5",
      "url": "https://www.youtube.com/watch?v=deepmindVsgpt5",
      "published": "2025-10-18T15:42:00Z",
      "thumbnail": "https://i.ytimg.com/vi/deepmindVsgpt5/hqdefault.jpg"
    }
  ],
  "retrievedAt": "2025-10-22 14:33:00"
}

# Tool 4 YouTube 동영상 URL로부터 댓글 수집 예시
[
  {
    "author": "JaneTech",
    "text": "This update from OpenAI is mind-blowing! Can't wait to try GPT-5!",
    "likeCount": 152,
    "publishedAt": "2025-10-21T09:32:00Z"
  },
  {
    "author": "AI_Nerd",
    "text": "Interesting insights. I think this will redefine AI-assisted content creation.",
    "likeCount": 87,
    "publishedAt": "2025-10-21T10:05:00Z"
  },
  {
    "author": "FutureCoder",
    "text": "Wish they’d show more real-world examples. Still, amazing progress!",
    "likeCount": 45,
    "publishedAt": "2025-10-21T11:50:00Z"
  }
]
